# %% [markdown]
# ![444.PNG](attachment:444.PNG)

# %% [markdown]
# * __단기체류__: 관광, 방문 등의 목적으로 90일 이하
# * 장기체류: 유학, 결혼 등의 목적으로 90일 이상
# * CHN > ETC > HKG > USA > MYS

# %% [markdown]
# ### 일자별 외국인 방문인구
# * 코로나 영향 치명적 -> 특히 단기체류니까
# * 우리는 특히 7, 8월 데이터 예측이니까 이 경향을 반영하는게 중요할 듯
# * 하지만 이 외국인 인구가 음쓰량에 유의미한 영향을 미치는지는 고민 필요

# %% [markdown]
# ![111.PNG](attachment:111.PNG)

# %%
import pandas  as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df4 = pd.read_csv('02-3_단기체류 외국인 유동인구_SHORT_TERM_FRGN.CSV.csv', encoding='cp949')

# %%
plt.figure(figsize=(10,10))
cor=df4.corr()
sns.heatmap(cor,annot=True,cmap=plt.cm.Purples)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.distplot(df4['visit_pop_cnt'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='visit_pop_cnt', ylabel='Density'>
