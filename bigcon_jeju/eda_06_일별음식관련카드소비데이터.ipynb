# %% [markdown]
# ![666.PNG](attachment:666.PNG)

# %% [markdown]
# * 결제건수와 결제금액: 아주 강한 상관관계 -> 당연함

# %% [markdown]
# ### 음식 업종별 결제 금액
# * 분류가 되게 애매하다고 생각함
# * 마트/슈퍼마켓과 식품/간식 등의 차이는?
# * 양식, 한식, 패스트푸드 등은 외식 -> 음식점 쓰레기와 연관
# * 나머지는 배달 등 -> 거주지 발생 쓰레기와 연관
# * 간식 = 카페/디저류인가?
# * 음식 결제금액이 음쓰량과 정비례할지는 모르겠지만 어느 정도 관련이 있을 것 같음
# > 1) 결제금액 -> 집/외식으로 크게 나누고 <br>
# > 2) 집-거주지 음쓰(주어진 데이터) <br>
# > 3) 외식-음식점 음쓰로 생각하면 <br>
# > 4) 최종 음쓰: 집+외식 비율을 합쳐서 예측

# %% [markdown]
# ![222.PNG](attachment:222.PNG)

# %%
import pandas  as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df6 = pd.read_csv('04_음식관련 카드소비_CARD_SPENDING.CSV.csv', encoding='cp949')

# %%
plt.figure(figsize=(10,10))
cor=df6.corr()
sns.heatmap(cor,annot=True,cmap=plt.cm.Purples)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.distplot(df6['use_amt'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='use_amt', ylabel='Density'>
