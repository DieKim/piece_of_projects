# %% [markdown]
# ![555.PNG](attachment:555.PNG)

# %% [markdown]
# * 기준년도 비율 동일(2021 제외)
# * 행정동 비율 동일
# * 성별 비율 동일
# * 주민등록 거주인구와 총 거주인구는 거의 같음: 아주 강한 상관관계(=1)
# * 외국인 거주인과 총 거주 인구: 중간~높은 상관관계 존재

# %% [markdown]
# ### 행정동별 총/외국인 거주인구

# %% [markdown]
# * 총 거주인구 대비 외국인 거주인구가 많은 동 존재 -> 근데 이걸 음쓰랑 연결짓긴 정보 부족
# * 외국인 비율이 음쓰랑 관련이 있을까?

# %% [markdown]
# ![444.PNG](attachment:444.PNG)

# %%
import pandas  as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df5 = pd.read_csv('03_거주인구_RESIDENT_POP.CSV.csv', encoding='cp949')

# %%
# 전체 인구나 등록 인구나 같다고 봐도 됨
plt.figure(figsize=(10,10))
cor=df5.corr()
sns.heatmap(cor,annot=True,cmap=plt.cm.Purples)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.distplot(df5['total_pop'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_pop', ylabel='Density'>
