# %% [markdown]
# ![333.PNG](attachment:333.PNG)

# %% [markdown]
# * 단기체류: 관광, 방문 등의 목적으로 90일 이하
# * __장기체류__: 유학, 결혼 등의 목적으로 90일 이상
# * CHN > VNM > USA > IDN > ETC
# * 모델링과는 별개로 저번에 성택오빠가 말한 과일 껍데기, 치킨 뼈 등 음쓰가 아닌 것에 대한 잘못된 배출과 관련 지어서 음쓰 감소 방안으로 연결지을 수 있지 않을까?

# %% [markdown]
# * 서울시 음쓰 기사: http://www.iloveorganic.co.kr/news/articleView.html?idxno=308596
#
# > 서울시 피셜 외국인이 많이 거주하는 자치구에서 쓰레기 무단투기 민원이 지속적으로 제기된다고 함
#
# * 외국인 쓰레기 기사: http://m.kyeongin.com/view.php?key=20200525010005225
#
# > 외국인 주민은 보통 쓰레기 배출 방식을 잘 몰라서 무단투기 문제 심각 -> 관련 제도의 필요성 대두

# %%
import pandas  as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df3 = pd.read_csv('02-2_장기체류 외국인 유동인구_LONG_TERM_FRGN.CSV.csv', encoding='cp949')

# %%
plt.figure(figsize=(10,10))
cor=df3.corr()
sns.heatmap(cor,annot=True,cmap=plt.cm.Purples)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.distplot(df3['visit_pop_cnt'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='visit_pop_cnt', ylabel='Density'>

# %%
plt.figure(figsize=(30, 10))
plt.plot(df3['base_date'], df3['visit_pop_cnt'], "-")
